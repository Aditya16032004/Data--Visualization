# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya16032004/Data--Visualization/blob/main/Data_visualization2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
iris=sns.load_dataset ("iris")

# %%
sns.lineplot(data=iris,x="sepal_length", y="petal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.lineplot(data=iris,x="sepal_length", y="petal_length",hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.regplot(data=iris,x="sepal_length", y="petal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.jointplot(data=iris,x="sepal_length", y="petal_length")

# %%
sns.pairplot(data=iris)

# %% [markdown]
# heatmap

# %%
corr= iris.corr()
# Out:
# <ipython-input-54-c5eecd410b1f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= iris.corr()

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.boxplot(data=iris)
# Out:
# <Axes: >

# %% [markdown]
# Histogram

# %%
import numpy as np

# %%
x= np.random.randn(1000)
plt.hist(x,bins=50)
# Out:
# (array([ 3.,  2.,  3.,  3.,  5., 15., 11.,  8.,  6., 11., 13., 12., 14.,
#         20., 22., 22., 26., 25., 34., 39., 41., 43., 37., 36., 46., 30.,
#         40., 52., 39., 32., 28., 43., 35., 28., 31., 25., 17., 19., 14.,
#         14., 12., 11.,  9.,  2.,  5.,  4.,  2.,  4.,  4.,  3.]),
#  array([-2.70996669, -2.60300346, -2.49604023, -2.389077  , -2.28211377,
#         -2.17515054, -2.0681873 , -1.96122407, -1.85426084, -1.74729761,
#         -1.64033438, -1.53337115, -1.42640792, -1.31944469, -1.21248146,
#         -1.10551823, -0.998555  , -0.89159176, -0.78462853, -0.6776653 ,
#         -0.57070207, -0.46373884, -0.35677561, -0.24981238, -0.14284915,
#         -0.03588592,  0.07107731,  0.17804054,  0.28500378,  0.39196701,
#          0.49893024,  0.60589347,  0.7128567 ,  0.81981993,  0.92678316,
#          1.03374639,  1.14070962,  1.24767285,  1.35463608,  1.46159932,
#          1.56856255,  1.67552578,  1.78248901,  1.88945224,  1.99641547,
#          2.1033787 ,  2.21034193,  2.31730516,  2.42426839,  2.53123162,
#          2.63819486]),
#  <BarContainer object of 50 artists>)

# %%
plt.imshow(corr)
